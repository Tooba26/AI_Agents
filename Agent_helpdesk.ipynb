# %% [markdown]
# <a href="https://colab.research.google.com/github/Tooba26/AI_Agents/blob/main/Agent_helpdesk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation
# - Install llama
# - Install Python

# %%
# !apt-get install -y zstd pciutils -qq
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Selecting previously unselected package pci.ids.
# (Reading database ... 122809 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2024.03.31-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2024.03.31-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.10.0-2build1_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.10.0-2build1) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.10.0-2build1_amd64.deb ...
# Unpacking pciutils (1:3.10.0-2build1) ...
# Selecting previously unselected package zstd.
# Preparing to unpack .../zstd_1.5.5+dfsg2-2build1.1_amd64.deb ...
# Unpacking zstd (1.5.5+dfsg2-2build1.1) ...
# Setting up pci.ids (0.0~2024.03.31-1ubuntu0.1) ...
# Setting up libpci3:amd64 (1:3.10.0-2build1) ...
# Setting up zstd (1.5.5+dfsg2-2build1.1) ...
# Setting up pciutils (1:3.10.0-2build1) ...
# Processing triggers for man-db (2.12.0-4build2) ...
# ...

# %%
import subprocess, time
subprocess.Popen(["ollama", "serve"])
time.sleep(5)
# !ollama pull llama3.1:8b

# %%
# !pip install -q ollama chromadb gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import os
os.makedirs("docs", exist_ok=True)
open("docs/hr_policy.txt", "w").write(
"""Annual leave: Full-time employees get 20 days of paid annual leave per year.

Sick leave: Employees get 10 days of paid sick leave. A doctor's note is required after 3 days."""
)
# Out:
# 173

# %%
# %%writefile agent.py
# Out:
# Writing agent.py

# %%
import gradio as gr
from agent import run_agent, ingest

ingest()

def chat(message, history):
    clean = [{"role": m["role"], "content": m["content"]} for m in history]
    return run_agent(message, clean)

gr.ChatInterface(chat, title="Helpdesk Agent").launch(share=True, debug=True)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 53.7MiB/s]
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://fc9bd1f407903d37a8.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fc9bd1f407903d37a8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [audit] search_docs({'query': 'annual leave policy'})
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/gradio/queueing.py", line 882, in process_events
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
